# %%
from run.run_V2 import *
# Out:
# D:\miniconda3\envs\speech_recognition_new\lib\site-packages\torchaudio\extension\extension.py:13: UserWarning: torchaudio C++ extension is not available.
#   warnings.warn('torchaudio C++ extension is not available.')
# new registry table has been added: preprocessor_classes
# If you want to use the speaker diarization, please `pip install hdbscan`
# If you want use mossformer, lease install rotary_embedding_torch by:
#  pip install -U rotary_embedding_torch
# If you want use mossformer, lease install rotary_embedding_torch by:
#  pip install -U rotary_embedding_torch
# Please Requires the ffmpeg CLI and `ffmpeg-python` package to be installed.
# If you want use mossformer, lease install rotary_embedding_torch by:
#  pip install -U rotary_embedding_torch
# If you want use mossformer, lease install rotary_embedding_torch by:
#  pip install -U rotary_embedding_torch

# %%
rs_dict = getSongFeat(song_name="qilai", input_mode="scp")

# %%
rs_dict
# Out:
# {'cst.wav': {'eigen_list': [{'word': '起',
#     'eigen': {'start_time': 0.77,
#      'end_time': 1.17,
#      'freq': 173.529,
#      'times': 0.4}},
#    {'word': '来',
#     'eigen': {'start_time': 1.17,
#      'end_time': 2.27,
#      'freq': 217.374,
#      'times': 1.1}},
#    {'word': '不',
#     'eigen': {'start_time': 2.27,
#      'end_time': 2.61,
#      'freq': 214.877,
#      'times': 0.34}},
#    {'word': '愿',
#     'eigen': {'start_time': 2.61,
#      'end_time': 3.17,
#      'freq': 219.266,
#      'times': 0.56}},
#    {'word': '做',
#     'eigen': {'start_time': 3.17,
#      'end_time': 3.41,
#      'freq': 222.455,
#      'times': 0.24}},
#    {'word': '努',
#     'eigen': {'start_time': 3.41,
#      'end_time': 3.69,
#      'freq': 152.821,
#      'times': 0.28}},
#    {'word': '力',
#     'eigen': {'start_time': 3.69,
#      'end_time': 3.85,
#      'freq': 164.264,
#      'times': 0.16}},
#    {'word': '的',
#     'eigen': {'start_time': 3.85,
#      'end_time': 4.05,
# ...

# %%
# 其中一首歌的特征字典
rs_dict["cst.wav"]["eigen_list"]
# Out:
# [{'word': '起',
#   'eigen': {'start_time': 0.77,
#    'end_time': 1.17,
#    'freq': 173.529,
#    'times': 0.4}},
#  {'word': '来',
#   'eigen': {'start_time': 1.17,
#    'end_time': 2.27,
#    'freq': 217.374,
#    'times': 1.1}},
#  {'word': '不',
#   'eigen': {'start_time': 2.27,
#    'end_time': 2.61,
#    'freq': 214.877,
#    'times': 0.34}},
#  {'word': '愿',
#   'eigen': {'start_time': 2.61,
#    'end_time': 3.17,
#    'freq': 219.266,
#    'times': 0.56}},
#  {'word': '做',
#   'eigen': {'start_time': 3.17,
#    'end_time': 3.41,
#    'freq': 222.455,
#    'times': 0.24}},
#  {'word': '努',
#   'eigen': {'start_time': 3.41,
#    'end_time': 3.69,
#    'freq': 152.821,
#    'times': 0.28}},
#  {'word': '力',
#   'eigen': {'start_time': 3.69,
#    'end_time': 3.85,
#    'freq': 164.264,
#    'times': 0.16}},
#  {'word': '的',
#   'eigen': {'start_time': 3.85,
#    'end_time': 4.05,
#    'freq': 185.984,
#    'times': 0.2}},
#  {'word': '人',
#   'eigen': {'start_time': 4.05,
# ...

# %%
notation_feat_dict = getSheetMusicFeatDict()
notation_feat_dict["G"]
# Out:
# {'bpm': 120,
#  'key_signature': 'G',
#  'time_signature': [2, 4],
#  'eigen_list': [{'word': '起', 'eigen': {'note': [293.665], 'time': [0.25]}},
#   {'word': '来', 'eigen': {'note': [392.0], 'time': [0.75]}},
#   {'word': '不', 'eigen': {'note': [392.0], 'time': [0.25]}},
#   {'word': '愿', 'eigen': {'note': [392.0], 'time': [0.375]}},
#   {'word': '做', 'eigen': {'note': [392.0], 'time': [0.125]}},
#   {'word': '奴', 'eigen': {'note': [293.665], 'time': [0.25]}},
#   {'word': '隶', 'eigen': {'note': [329.63], 'time': [0.125]}},
#   {'word': '的', 'eigen': {'note': [370.495], 'time': [0.125]}},
#   {'word': '人', 'eigen': {'note': [392.0], 'time': [0.5]}},
#   {'word': '们', 'eigen': {'note': [392.0], 'time': [0.5]}},
#   {'word': '把', 'eigen': {'note': [494.88], 'time': [0.25]}},
#   {'word': '我', 'eigen': {'note': [392.0], 'time': [0.25]}},
#   {'word': '们', 'eigen': {'note': [440.0], 'time': [0.125]}},
#   {'word': '的', 'eigen': {'note': [494.88], 'time': [0.125]}},
# ...

# %%
calDtwFreqAndTempo(notation_feat_dict=notation_feat_dict, batch_pwf_dict=rs_dict)
# Out:
# {'cst.wav': ('E',
#   {'freq_dist_normalized': 0.3083975405511764,
#    'tempo_dist_normalized': 0.275894427002489}),
#  'qilai.wav': ('B',
#   {'freq_dist_normalized': 0.09142393987730096,
#    'tempo_dist_normalized': 0.28477736613368904}),
#  'qilai_1.wav': ('A#',
#   {'freq_dist_normalized': 0.24247883312841545,
#    'tempo_dist_normalized': 0.3621734876074319}),
#  'qilai_2.wav': ('B',
#   {'freq_dist_normalized': 0.3559143507196616,
#    'tempo_dist_normalized': 0.3258858321590013}),
#  'qilai_3.wav': ('E',
#   {'freq_dist_normalized': 0.25244456758957434,
#    'tempo_dist_normalized': 0.30404931003470415}),
#  'qilai_4.wav': ('G',
#   {'freq_dist_normalized': 0.1937874628243162,
#    'tempo_dist_normalized': 0.3187036439569805}),
#  'song_demo.wav': ('C',
#   {'freq_dist_normalized': 0.25104352535570557,
#    'tempo_dist_normalized': 0.29778863153342994})}
